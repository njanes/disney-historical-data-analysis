# %% [markdown]
# # Exploratory Data Analysis of Historical Disney Data

# %% [markdown]
# # Introduction
#
# ## Questions of interest
# In this analysis, I will be evaluating questions related to the Disney dataset. I would like to investigate to determine:
#
# > 1. Which genre of movie has generated Disney the most revenue?
# > 2. In which genre of movie has Disney produced the most films?
#
# Adventure movies are popular as they often provide a family-friendly viewing experience, with immersive storylines and captivating scenes and soundtracks. Due to its popularity and accesssabililty to all audiences, I would like to see whether adventure is the top-grossing Disney genre. I expect that this will be the case.
#
# I expect that the films with the highest gross will also have the highest number of productions (and vice versa). Disney would prefer to produce films which gross the highest, so executives often make business decisions based on past performance, and would therefore produce more films in the genre that generates the most income.
#
# ## Dataset description
#
# The following description is an exerpt from the [website](https://data.world/kgarrett/disney-character-success-00-16) where the dataset was found:
#
# "This dataset explores the box office data of Walt Disney Studios from 2000 to 2016. It includes information on the movie title, release date, main character, villain, and songs associated with each film. This dataset provides insights into how different elements contribute to a movie's success or failure
#
# When exploring this dataset, there are a few things to keep in mind. Firstly, the data is divided into four different files: `disney-characters.csv`, `disney_movies_total_gross.csv`, `disney-voice-actors.csv`, and `disney_revenue_1991-2016.csv`. Each of these files contains information on different aspects of Disney's box office data.
#
# To make things easier, we've created a quick guide that outlines what you can find in each file:"
#
# * **disney-characters.csv**
#     * This file contains information on the movie title, release date, main character, villain, and songs associated with each film
# * **disney_movies_total_gross.csv**
#     * This file includes data on the total gross of Walt Disney Studios movies from 2000 to 2016
# * **disney-voice-actors.csv**
#     * This file contains information on the voice actors for Disney characters
# * **disney_revenue_1991-2016.csv**
#     * This file contains data on the revenue of the Walt Disney Company from 1991 to 2016

# %% [markdown]
# # Methods and Results
#
# First, I will import the csv files and visualize the data.
# I will only be importing the **disney_movies_total_gross** file as I am only interested in the `genre` and `inflation_adjusted_gross` variables. I want to create a data frame containing the columns *genre*, *inflation_adjusted_gross*, and a new column *productions* containing the number of movies made in each genre.

# %%
# import required libraries
import altair as alt
import pandas as pd
import numpy as np

# Enable PNG rendering
alt.renderers.enable("png")

# import Disney data
data = pd.read_csv("data/disney_movies_total_gross.csv")

# %% [markdown]
# Now, I will use the `head()` method to view the first 5 rows of the data frame

# %%
# get first 5 rows of data
data.head()
# Out:
#                        movie_title  release_date      genre MPAA_rating  \
# 0  Snow White and the Seven Dwarfs  Dec 21, 1937    Musical           G
# 1                        Pinocchio   Feb 9, 1940  Adventure           G
# 2                         Fantasia  Nov 13, 1940    Musical           G
# 3                Song of the South  Nov 12, 1946  Adventure           G
# 4                       Cinderella  Feb 15, 1950      Drama           G
#
#     total_gross inflation_adjusted_gross
# 0  $184,925,485           $5,228,953,251
# 1   $84,300,000           $2,188,229,052
# 2   $83,320,000           $2,187,090,808
# 3   $65,000,000           $1,078,510,579
# 4   $85,000,000             $920,608,730

# %% [markdown]
# **Table 1: First 5 rows of data frame data**

# %% [markdown]
# Using the `info()` method, I can view more information about the data, such as the length, column names and data types.

# %%
# get data frame shape and column dtypes
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    str
#  1   release_date              579 non-null    str
#  2   genre                     562 non-null    str
#  3   MPAA_rating               523 non-null    str
#  4   total_gross               579 non-null    str
#  5   inflation_adjusted_gross  579 non-null    str
# dtypes: str(6)
# memory usage: 27.3 KB

# %% [markdown]
# **Table 2: Data frame shape, columns, dtypes, and memory information**

# %% [markdown]
# The data frame has $579$ rows and $6$ columns. For every movie_title, there is a release_date, MPAA_rating, total_gross, and inflation_adjusted_gross.

# %% [markdown]
# ### Calculating Total Gross and Number of Productions by Genre
#
# By applying the `loc()` method to the **data** data frame, I create a new dataframe containing only the columns **movie_title**, **genre**, **inflation_adjusted_gross**, and **release_date**

# %%
# create data frame with select columns
movies = data.loc[:, ["movie_title", "genre", "inflation_adjusted_gross", "release_date"]]
movies
# Out:
#                          movie_title      genre inflation_adjusted_gross  \
# 0    Snow White and the Seven Dwarfs    Musical           $5,228,953,251
# 1                          Pinocchio  Adventure           $2,188,229,052
# 2                           Fantasia    Musical           $2,187,090,808
# 3                  Song of the South  Adventure           $1,078,510,579
# 4                         Cinderella      Drama             $920,608,730
# ..                               ...        ...                      ...
# 574         The Light Between Oceans      Drama              $12,545,979
# 575                   Queen of Katwe      Drama               $8,874,389
# 576                   Doctor Strange  Adventure             $232,532,923
# 577                            Moana  Adventure             $246,082,029
# 578     Rogue One: A Star Wars Story  Adventure             $529,483,936
#
#      release_date
# 0    Dec 21, 1937
# 1     Feb 9, 1940
# 2    Nov 13, 1940
# ...

# %% [markdown]
# Next, I import a script called **func_script** which contains a function `char_del()` that accepts a dataframe, columns, and a list of character strings, then returns the dataframe with strings removed from the designated columns.
#
# This script also contains a function `col_div()` that accepts a dataframe, a column, and an integer, then returns the dataframe with the specified column as type int64 and divided by the integer.
#
# I use the `char_del()` custom function to format the *inflation_adjusted_gross* column by removing the currency symbol and commas. Then, I use the `col_div()` custom function to change the type of *inflation_adjusted_gross* column to int64 to avoid an OverflowError and divide by 1,000,000 and for readability.

# %%
# import custom modules
import func_script as fs

# remove '$' and ',' from inflation_adjusted_gross
fs.char_del(movies, ["inflation_adjusted_gross"], ["$", ","])

# change type to int64 and divide by 1,000,000
fs.col_div(movies, "inflation_adjusted_gross", 1000000)

# group by genre, sum inflation_adjusted_gross, and count movie_title
movies_grouped = movies.groupby(by="genre", as_index=False).agg(
    {"inflation_adjusted_gross": "sum", "movie_title": "count"}
)

# rename columns to reflect values
movies_grouped = movies_grouped.reset_index(drop=True).rename(
    {"inflation_adjusted_gross": "total_gross_M", "movie_title": "movie_count"},
    axis="columns",
)
movies_grouped
# Out:
#                   genre  total_gross_M  movie_count
# 0                Action    5498.936786           40
# 1             Adventure   24561.266158          129
# 2          Black Comedy     156.730475            3
# 3                Comedy   15409.526913          182
# 4   Concert/Performance     114.821678            2
# 5           Documentary     203.488418           16
# 6                 Drama    8195.804484          114
# 7                Horror     140.483092            6
# 8               Musical    9657.565776           16
# 9       Romantic Comedy    1788.872933           23
# 10    Thriller/Suspense    2151.690954           24
# 11              Western     516.709946            7

# %% [markdown]
# **Table 3: Cleaned and grouped data frame. Contains total gross in \$M USD, and count of movies by genre.**

# %% [markdown]
# *Note: 17 of the 579 movies have no listed genre and are dropped by the `groupby()` above. The totals in Table 3 reflect the 562 movies with a genre recorded.*

# %% [markdown]
# ### Visualizing Total Gross and Number of Productions by Genre
#
# I will plot the total gross in millions by genre, which will give a numerical representation of viewers' preference of genre. The public is likely to re-watch and recommend movies they like to others, and as such, this will be reflected in the gross of movies (and thereby genres).
#
# I will also visualize the number of movies produced by Disney for every genre. This will give an idea of Disney's preference of genre, as a higher number of films produced indicates a preference by Disney to produce a given genre.

# %%
gross_plot = (
    alt.Chart(movies_grouped)
    .mark_bar(color="#b30047")
    .encode(
        x=alt.X("genre", title="Genre", sort="-y"),
        y=alt.Y("total_gross_M", title="Total Gross ($M USD)"),
    )
    .properties(
        title="Figure 1: Total Gross by Genre in Millions (Inflation Adjusted)",
        height=350,
        width=600,
    )
    .configure_title(fontSize=20, dy=-20, dx=-40)
    .configure_axis(
        titleFontSize=16,
        labelFontSize=12,
    )
    .configure_axisX(labelAngle=-45, titleX=260, titleY=105)
    .configure_axisY(titleX=-70)
)
gross_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# From the chart above (figure 1), we see that the genre with the highest total gross is Adventure *(\$24561.27M)*, followed by Comedy *(\$15409.53M)* and Musical *(\$9657.57M)*. The genre with the least total gross is Concert/Performance, with a value of *(\$114.82M)*.

# %%
prod_plot = (
    alt.Chart(movies_grouped)
    .mark_bar(color="#003f97")
    .encode(
        x=alt.X("genre", title="Genre", sort="-y"),
        y=alt.Y("movie_count", title="Number of Productions"),
    )
    .properties(
        title="Figure 2: Total Movie Productions by Genre", height=350, width=600
    )
    .configure_title(fontSize=20, dy=-20, dx=-40)
    .configure_axis(
        titleFontSize=16,
        labelFontSize=12,
    )
    .configure_axisX(labelAngle=-45, titleX=260, titleY=105)
    .configure_axisY(titleX=-70)
)
prod_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# As illustrated above (figure 2), the genre with the most productions is Comedy (*182*), followed by Adventure (*129*) and Drama (*114*). The genre with the least productions is Concert/Performance, with a mere *2* titles.

# %% [markdown]
# # Discussion
#
# This project showcases the analysis of the Disney dataset. The objective was to attempt to evaluate which genre of movie generates Disney the most income, and which genre is most produced by Disney.
#
# The genre with the highest total gross is Adventure (figure 1), which I had expected. However, I did not expect the result that was obtained for the genre with most productions.
#
# The genre in which Disney produces the most films is Comedy (figure 2), which was an unexpected result. Despite having a lesser total gross than adventure, comedy films are produced in considerably higher numbers. It may be that Disney produces the most comedy movies because they cost the least time and money to produce, and so they are made in large numbers to compensate for their lower average gross. If these productions cost less, Disney may be inclined to prioritize quantity over quality, and this may contribute to the lower gross per production for comedy films.
#
# It would be interesting to look at the average cost of production for each genre, as it would provide a better insight into why Disney may opt to produce more or less films in a given genre. As stated above, I would expect that Disney produces the most films in the genre with the lowest average production cost.
#
# The Extended Analysis section below follows up on this directly: it normalizes gross by production count, breaks the results down by decade, and checks whether films with a named villain gross differently, without needing production cost data.

# %% [markdown]
# # Extended Analysis
#
# To expand on the existing analysis above, I aim to answer 3 additional questions:
#
# > 4. Which genre is the highest-grossing on a per-film basis?
# > 5. How has each genre's performance changed historically?
# > 6. Do films with a named antagonist gross higher than those without?

# %% [markdown]
# ## Average Gross per Movie
#
# Total gross doesn't distinguish between quality and quantity of films in a given genre. By dividing total gross by movie count, we can determine the average gross per production in each genre.

# %%
# add a per-movie average to the existing grouped table
movies_grouped["avg_gross_per_movie_M"] = (
    movies_grouped["total_gross_M"] / movies_grouped["movie_count"]
)
movies_grouped.sort_values("avg_gross_per_movie_M", ascending=False)
# Out:
#                   genre  total_gross_M  movie_count  avg_gross_per_movie_M
# 8               Musical    9657.565776           16             603.597861
# 1             Adventure   24561.266158          129             190.397412
# 0                Action    5498.936786           40             137.473420
# 10    Thriller/Suspense    2151.690954           24              89.653790
# 3                Comedy   15409.526913          182              84.667730
# 9       Romantic Comedy    1788.872933           23              77.777084
# 11              Western     516.709946            7              73.815707
# 6                 Drama    8195.804484          114              71.893022
# 4   Concert/Performance     114.821678            2              57.410839
# 2          Black Comedy     156.730475            3              52.243492
# 7                Horror     140.483092            6              23.413849
# ...

# %% [markdown]
# **Table 4: Total gross, number of releases, and average gross per movie by genre**

# %%
avg_plot = (
    alt.Chart(movies_grouped)
    .mark_bar(color="#f39237")
    .encode(
        x=alt.X("genre", title="Genre", sort="-y"),
        y=alt.Y("avg_gross_per_movie_M", title="Avg. Gross per Movie ($M USD)"),
    )
    .properties(
        title="Figure 3: Average Gross per Movie by Genre", height=350, width=600
    )
    .configure_title(fontSize=20, dy=-20, dx=-40)
    .configure_axis(
        titleFontSize=16,
        labelFontSize=12,
    )
    .configure_axisX(labelAngle=-45, titleX=260, titleY=105)
    .configure_axisY(titleX=-70)
)
avg_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# Musical has the highest average gross per movie ($603.6M), more than three times Adventure's per-movie average ($190.4M), despite having produced only 16 films to Adventure's 129.
#
# This provides additional insight beyond figures 1 and 2, showing that Adventure's lead is a volume effect, not a per-film effect. A few Musical films (e.g., *Snow White and the Seven Dwarfs*, adjusted to over $5B) constitute a large share of the genre's total gross, so this average is sensitive to those few films rather than reflecting a consistently high-grossing genre.

# %% [markdown]
# ## Genre Performance Over Time
#
# The totals in Table 3 span nearly 80 years of releases (1937-2016) but don't provide any insight into trends over time. By grouping inflation-adjusted gross by decade, we can assess whether Adventure's lead is a long-standing pattern or a more recent shift.

# %%
# extract decade from release_date
movies["release_date_dt"] = pd.to_datetime(movies["release_date"])
movies["decade"] = (movies["release_date_dt"].dt.year // 10) * 10

# limit to the 5 highest-grossing genres overall, for readability
top_genres = (
    movies_grouped.sort_values("total_gross_M", ascending=False)["genre"]
    .head(5)
    .tolist()
)
decade_genre = (
    movies[movies["genre"].isin(top_genres)]
    .groupby(["decade", "genre"], as_index=False)["inflation_adjusted_gross"]
    .sum()
)
decade_genre.head()
# Out:
#    decade      genre  inflation_adjusted_gross
# 0    1930    Musical               5228.953251
# 1    1940  Adventure               3266.739631
# 2    1940    Musical               2187.090808
# 3    1950  Adventure                528.279994
# 4    1950      Drama               2178.150077

# %%
time_plot = (
    alt.Chart(decade_genre)
    .mark_line(point=True)
    .encode(
        x=alt.X("decade:O", title="Decade"),
        y=alt.Y("inflation_adjusted_gross", title="Total Gross ($M USD)"),
        color=alt.Color("genre", title="Genre", scale=alt.Scale(
            domain=['Adventure', 'Comedy', 'Musical', 'Drama', 'Action'],
            range=["#b30047", "#003f97", "#f39237", "#60a561", "#bd3bcd"]
        )),
    )
    .properties(
        title="Figure 4: Total Gross by Decade for Top 5 Genres", height=350, width=750
    )
    .configure_title(fontSize=20, dy=-20)
    .configure_axis(
        titleFontSize=16,
        labelFontSize=12,
    )
    .configure_axisX(labelAngle=-45, titleX=310, titleY=55)
    .configure_axisY(titleX=-70)
    .configure_legend(
        titleFontSize=14,
        labelFontSize=12,
        padding=10,
        symbolType='square'
    )
)
time_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# **Adventure's dominance is recent, not historic.** Musical led every decade from the 1930s through the 1960s; Comedy and Adventure only pull ahead starting in the 1980s-90s, and Adventure doesn't take a clear lead until the 2000s and 2010s. The all-time total in Figure 1 obscures this: it reads as if Adventure has always been Disney's strongest genre, when it's actually a shift that's taken place mostly in the last ~25 years, likely tied to the studio's franchise-driven blockbuster strategy in that period.

# %% [markdown]
# ## Story Elements and Gross: Does a Named Villain Matter?
#
# The dataset also includes `disney-characters.csv`, which lists the hero, villain, and signature song for a subset of (mostly classic, animated) Disney films. Joining it to the gross data tests whether films with a clearly named antagonist gross differently than films without one.
#
# *Note: this file only covers 108 films, mostly older animated features, and only 47 of those match by exact title to the gross dataset. This is a much smaller and less representative sample than the 562-movie set used above, so results here are suggestive rather than conclusive.*

# %%
# load and clean the characters file (titles have a leading newline in the source CSV)
characters = pd.read_csv("data/disney-characters.csv")
characters["movie_title"] = (
    characters["movie_title"].str.replace("\n", "", regex=False).str.strip()
)

# join to the cleaned movies data on title
char_merged = movies.merge(
    characters[["movie_title", "hero", "villian", "song"]],
    on="movie_title",
    how="inner",
)
char_merged["has_villain"] = (
    char_merged["villian"].notna().map({True: "Named villain", False: "No villain"})
)

print(
    f"Matched {len(char_merged)} of {len(characters)} character-file movies to the gross data."
)
villain_summary = char_merged.groupby("has_villain", as_index=False).agg(
    avg_gross_M=("inflation_adjusted_gross", "mean"),
    movie_count=("movie_title", "count"),
)
villain_summary
# Out:
# Matched 47 of 56 character-file movies to the gross data.
#      has_villain  avg_gross_M  movie_count
# 0  Named villain   471.722091           42
# 1     No villain   165.446570            5

# %%
villain_plot = (
    alt.Chart(villain_summary)
    .mark_bar(color="#60a561")
    .encode(
        x=alt.X("has_villain", title=""),
        y=alt.Y("avg_gross_M", title="Avg. Inflation-Adjusted Gross ($M USD)"),
    )
    .properties(
        title="Figure 5: Average Gross, Movies With vs. Without a Named Villain",
        height=350,
        width=600,
    )
    .configure_title(fontSize=20, dy=-20, dx=-40)
    .configure_axis(
        titleFontSize=16,
        labelFontSize=12,
    )
    .configure_axisX(labelAngle=0, labelPadding=20,labelFontSize=14, titleX=260, titleY=105)
    .configure_axisY(titleX=-70)
)
villain_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# Films with a named villain in this subset average $471.7M versus $165.4M for films without one.
#
# This is a large gap, but the "no villain" group is only 5 films, so it isn't reliable evidence on its own; a larger, purpose-built sample (or a formal test) would be needed to say this relationship holds generally rather than reflecting which 5 films happened to lack a listed villain.

# %% [markdown]
# ## Resources used
# * [Data Source](https://data.world/kgarrett/disney-character-success-00-16)
#     * The dataset used in this project was compiled by Kelly Garrett.
# * [Plot Styling](https://altair-viz.github.io/user_guide/customization.html#)
#     * Documentation for Altair plot styling
# * [Plot Configuration](https://altair-viz.github.io/altair-tutorial/notebooks/08-Configuration.html)
#     * Documentation for Altair plot elements configuration
# * `disney-characters.csv`, used in the Extended Analysis section, is from the same [data source](https://data.world/kgarrett/disney-character-success-00-16) above.
